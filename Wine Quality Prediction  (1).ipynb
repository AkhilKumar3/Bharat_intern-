# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\HP\Downloads\archive (7)\WineQT.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
sns.countplot(x='quality',data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
sns.scatterplot(x='fixed acidity',y='citric acid',data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='citric acid'>

# %%
#independent variable 
x=df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1138     11.0
# 1139      9.5
# 1140     10.5
# 1141     11.2
# 1142     10.2
#
# [1143 rows x 11 columns]

# %%
#dependent variable
y=df['quality']
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 420            9.0              0.45         0.49             2.6      0.084
# 914            7.0              0.60         0.30             4.5      0.068
# 179            8.0              0.57         0.23             3.2      0.073
# 844            6.2              0.43         0.22             1.8      0.078
# 146           12.8              0.30         0.74             2.6      0.095
# ..             ...               ...          ...             ...        ...
# 421            6.6              0.39         0.49             1.7      0.070
# 59             8.6              0.49         0.28             1.9      0.110
# 452            9.6              0.88         0.28             2.4      0.086
# 124            7.3              0.38         0.21             2.0      0.080
# 437           11.3              0.37         0.41             2.3      0.088
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 420                 21.0                  75.0  0.99870  3.35       0.57
# 914                 20.0                 110.0  0.99914  3.30       1.17
# 179                 17.0                 119.0  0.99675  3.26       0.57
# 844                 21.0                  56.0  0.99633  3.52       0.60
# 146                  9.0                  28.0  0.99940  3.20       0.77
# ..                   ...                   ...      ...   ...        ...
# 421                 23.0                 149.0  0.99220  3.12       0.50
# 59                  20.0                 136.0  0.99720  2.93       1.95
# 452                 30.0                 147.0  0.99790  3.24       0.53
# 124                  7.0                  35.0  0.99610  3.33       0.47
# 437                  6.0                  16.0  0.99880  3.09       0.80
#
#      alcohol
# 420      9.7
# 914     10.2
# 179      9.3
# 844      9.5
# 146     10.8
# ..       ...
# 421     11.5
# 59       9.9
# 452      9.4
# 124      9.5
# 437      9.3
#
# [914 rows x 11 columns]

# %%
x_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 507             8.9             0.565         0.34             3.0      0.093
# 493             5.1             0.470         0.02             1.3      0.034
# 426             8.5             0.585         0.18             2.1      0.078
# 289             8.6             0.725         0.24             6.6      0.117
# 143             9.6             0.320         0.47             1.4      0.056
# ...             ...               ...          ...             ...        ...
# 1102            7.0             0.570         0.02             2.0      0.072
# 206             8.7             0.520         0.09             2.5      0.091
# 586            12.6             0.410         0.54             2.8      0.103
# 382            12.9             0.350         0.49             5.8      0.066
# 782             8.1             0.780         0.10             3.3      0.090
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 507                  16.0                 112.0  0.99980  3.38       0.61
# 493                  18.0                  44.0  0.99210  3.90       0.62
# 426                   5.0                  30.0  0.99670  3.20       0.48
# 289                  31.0                 134.0  1.00140  3.32       1.07
# 143                   9.0                  24.0  0.99695  3.22       0.82
# ...                   ...                   ...      ...   ...        ...
# 1102                 17.0                  26.0  0.99575  3.36       0.61
# 206                  20.0                  49.0  0.99760  3.34       0.86
# 586                  19.0                  41.0  0.99939  3.21       0.76
# 382                   5.0                  35.0  1.00140  3.20       0.66
# 782                   4.0                  13.0  0.99855  3.36       0.49
#
#       alcohol
# 507       9.5
# 493      12.8
# 426       9.8
# 289       9.3
# 143      10.3
# ...       ...
# 1102     10.2
# 206      10.6
# 586      11.3
# 382      12.0
# 782       9.5
#
# [229 rows x 11 columns]

# %%
y_train
# Out:
# 420    5
# 914    5
# 179    5
# 844    6
# 146    7
#       ..
# 421    6
# 59     6
# 452    5
# 124    5
# 437    5
# Name: quality, Length: 914, dtype: int64

# %%
y_test
# Out:
# 507     5
# 493     6
# 426     6
# 289     5
# 143     7
#        ..
# 1102    5
# 206     7
# 586     6
# 382     7
# 782     5
# Name: quality, Length: 229, dtype: int64

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict([[9.0,0.45,0.49,2.6,0.084,21.0,75.0,0.99870,3.35,0.57,9.7]])
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([5.35481197])
